# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 Basic Protting: plot

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot();

# %%
np.random.randn(1000, 4)
# Out:
# array([[ 0.08375157,  0.61277998, -0.45620861,  1.30978506],
#        [ 0.22369288, -0.71038918,  1.10278057, -1.28079607],
#        [ 0.19843225,  1.737023  ,  0.22715358,  0.38077385],
#        ...,
#        [ 1.36238585, -0.13768945,  0.86300147, -2.34598906],
#        [ 0.70992948,  0.36400834,  0.33334657,  0.44286091],
#        [ 1.63277257, -0.9213385 , -1.30661852,  0.06284286]])

# %%
ts.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.plot(x='A', y='B')

# %% [markdown]
# # 2 Other Plots

# %% [raw]
# • ‘bar’ or ‘barh’ for bar plots
# • ‘hist’ for histogram
# • ‘box’ for boxplot
# • ‘kde’ or 'density' for density plots
# • ‘area’ for area plots
# • ‘scatter’ for scatter plots
# • ‘hexbin’ for hexagonal bin plots
# • ‘pie’ for pie plots

# %%
plt.figure();
df.iloc[5].plot(kind='bar')

# %% [markdown]
# ## 2.1 Bar plots

# %%
plt.figure();
df.iloc[5].plot.bar(); 
plt.axhline(0, color='k')

# %%
df.iloc[5].plot(kind='bar').axhline(0, color='k') # Mesmo resultado do anterior

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar(); # Multiplas colunas de barras

# %%
df2.plot.bar(stacked=True); # Empilhando gráficos

# %%
df2.plot.barh() # Graficos de barras na horizontal

# %%
df2.plot.barh(stacked=True)  # grafico na horizontal empilhado

# %% [markdown]
# ## 2.2 Histograms

# %%
df4 = pd.DataFrame({
    'a': np.random.randn(1000) + 1,
    'b': np.random.randn(1000),
    'c': np.random.randn(1000) - 1},
    columns=['a', 'b', 'c']
)

# %%
plt.figure();
df4.plot.hist(alpha=0.5)

# %%
plt.figure();
df4.plot.hist(stacked=True, bins=20) # empilhando os dados

# %%
plt.figure();
df4['a'].plot.hist(orientation='horizontal', cumulative=True)

# %%
plt.figure();

df['A'].diff().hist()

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.795496 -0.244689 -0.625011  1.155832
# 2000-01-02 -0.902113 -0.016438 -1.880140  2.328216
# 2000-01-03 -2.051614 -0.570672 -1.040355  1.319489
# 2000-01-04  0.125660 -1.481805 -1.680836  1.109172
# 2000-01-05  0.071872 -3.230056 -0.536679  0.183513

# %%
plt.figure();
df.diff().hist(color='k', alpha=0.5, bins=50) # verificando a diferença dos valores das colunas
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000274330EDDD8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027433172160>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))

# %%
data.head()
# Out:
# 0    0.277182
# 1    0.812767
# 2   -1.084950
# 3   -0.258363
# 4    0.684589
# dtype: float64

# %%
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027431C50710>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000274332DD4A8>]], dtype=object)

# %% [markdown]
# ## 2.3 Box Plots

# %%
df = pd.DataFrame(np.random.rand(10,5), columns=['A', 'B', 'C', 'D', 'E'])
df
# Out:
#           A         B         C         D         E
# 0  0.556258  0.056367  0.106882  0.447924  0.508437
# 1  0.666280  0.821624  0.820181  0.034645  0.561078
# 2  0.577164  0.496366  0.070633  0.701611  0.128611
# 3  0.912874  0.453557  0.725419  0.899766  0.684041
# 4  0.925768  0.792259  0.909107  0.199075  0.257626
# 5  0.953681  0.550001  0.038712  0.918859  0.668667
# 6  0.830958  0.825742  0.651401  0.712086  0.898915
# 7  0.822550  0.970341  0.668527  0.655448  0.474100
# 8  0.089279  0.851696  0.341698  0.746129  0.760731
# 9  0.328285  0.268785  0.506550  0.960724  0.519462

# %%
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')
color
# Out:
# {'boxes': 'DarkGreen',
#  'whiskers': 'DarkOrange',
#  'medians': 'DarkBlue',
#  'caps': 'Gray'}

# %%
df.plot.box(color=color, sym='r+')

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10, 5))

# %%
plt.figure();
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df
# Out:
#        Col1      Col2  X
# 0  0.471797  0.890394  A
# 1  0.277669  0.071860  A
# 2  0.623779  0.184677  A
# 3  0.376411  0.965885  A
# 4  0.669205  0.767271  A
# 5  0.262240  0.572618  B
# 6  0.662302  0.299101  B
# 7  0.442178  0.260482  B
# 8  0.588070  0.427789  B
# 9  0.317389  0.475168  B

# %%
df.boxplot()

# %%
plt.figure();
bp = df.boxplot(by='X')

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=['Col1', 'Col2', 'Col3'])

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df['Y'] = pd.Series(['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'])

# %%
df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.038350  0.384533  0.895875  A  A
# 1  0.919121  0.970768  0.293824  A  B
# 2  0.997092  0.255681  0.887616  A  A
# 3  0.238362  0.100389  0.413940  A  B
# 4  0.749384  0.015518  0.276637  A  A
# 5  0.283665  0.008051  0.098955  B  B
# 6  0.587407  0.563866  0.924117  B  A
# 7  0.148356  0.390947  0.220010  B  B
# 8  0.341459  0.359973  0.894487  B  A
# 9  0.094217  0.390100  0.496456  B  B

# %%
plt.figure();

# %%
bp = df.boxplot()

# %%
bp = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])

# %%
bp = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])

# %%
np.random.seed(1234)

# %%
df_box = pd.DataFrame(np.random.randn(50,2))

# %%
df_box['g'] = np.random.choice(['A', 'B'], size=50)

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  0.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696 -2.242685  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646 -0.655969  B
# 11  0.193421  0.553439  B
# 12  1.318152 -0.469305  B
# 13  0.675554 -1.817027  B
# 14 -0.183109  1.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  1.045938  B
# 17  0.863717 -0.122092  B
# 18  0.124713 -0.322795  B
# 19  0.841675  2.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142 -2.074978  B
# 22  0.247792 -0.897157  B
# 23 -0.136795  0.018289  B
# 24  0.755414  0.215269  B
# 25  0.841009 -1.445810  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242 -0.144620  B
# 28  0.354020 -0.035513  B
# 29  0.565738  1.545659  A
# 30 -0.974236 -0.070345  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# ...

# %%
df_box.loc[df_box['g'] == 'B', 1] += 3

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  3.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696  0.757315  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646  2.344031  B
# 11  0.193421  3.553439  B
# 12  1.318152  2.530695  B
# 13  0.675554  1.182973  B
# 14 -0.183109  4.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  4.045938  B
# 17  0.863717  2.877908  B
# 18  0.124713  2.677205  B
# 19  0.841675  5.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142  0.925022  B
# 22  0.247792  2.102843  B
# 23 -0.136795  3.018289  B
# 24  0.755414  3.215269  B
# 25  0.841009  1.554190  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242  2.855380  B
# 28  0.354020  2.964487  B
# 29  0.565738  1.545659  A
# 30 -0.974236  2.929655  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# ...

# %%
dp = df_box.boxplot(by='g')

# %%
dp = df_box.groupby('g').boxplot()

# %% [markdown]
# ## 2.4 Area Plot

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %% [markdown]
# ## 2.5 Scatter Plot

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(50,4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.scatter(x='a', y='b')

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')

# %%
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.figure();
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
plt.show()

# %%
df.plot.scatter(x='a', y='b', c='c', s=50);

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200);

# %% [markdown]
# ## 2.6 Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] = df['b'] + np.arange(1000)

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %% [markdown]
# ## 2.7 Pie plot
