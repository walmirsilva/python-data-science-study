# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 1 Basic Protting: plot

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = ts.cumsum()

# %%
ts.plot()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df = df.cumsum()

# %%
plt.figure(); df.plot();

# %%
np.random.randn(1000, 4)
# Out:
# array([[-0.40907208,  1.59735135,  0.36032038,  1.20012751],
#        [-0.56173562, -2.02319522, -0.41424185, -1.07408344],
#        [ 1.17976144, -0.19846969,  0.64409836,  0.30194557],
#        ...,
#        [ 0.82733888,  1.21792384,  0.46189277,  1.35567198],
#        [-0.29109456,  0.67465285, -1.72481067,  0.8676716 ],
#        [ 0.13274789, -1.87983344, -1.54825697,  0.39102437]])

# %%
ts.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10',
#                ...
#                '2002-09-17', '2002-09-18', '2002-09-19', '2002-09-20',
#                '2002-09-21', '2002-09-22', '2002-09-23', '2002-09-24',
#                '2002-09-25', '2002-09-26'],
#               dtype='datetime64[ns]', length=1000, freq='D')

# %%
df3 = pd.DataFrame(np.random.randn(1000, 2), columns=['B', 'C']).cumsum()

# %%
df3['A'] = pd.Series(list(range(len(df))))

# %%
df3.plot(x='A', y='B')

# %% [markdown]
# # 2 Other Plots

# %% [raw]
# • ‘bar’ or ‘barh’ for bar plots
# • ‘hist’ for histogram
# • ‘box’ for boxplot
# • ‘kde’ or 'density' for density plots
# • ‘area’ for area plots
# • ‘scatter’ for scatter plots
# • ‘hexbin’ for hexagonal bin plots
# • ‘pie’ for pie plots

# %%
plt.figure();
df.iloc[5].plot(kind='bar')

# %% [markdown]
# ## 2.1 Bar plots

# %%
plt.figure();
df.iloc[5].plot.bar(); 
plt.axhline(0, color='k')

# %%
df.iloc[5].plot(kind='bar').axhline(0, color='k') # Mesmo resultado do anterior

# %%
df2 = pd.DataFrame(np.random.rand(10, 4), columns=['a', 'b', 'c', 'd'])
df2.plot.bar(); # Multiplas colunas de barras

# %%
df2.plot.bar(stacked=True); # Empilhando gráficos

# %%
df2.plot.barh() # Graficos de barras na horizontal

# %%
df2.plot.barh(stacked=True)  # grafico na horizontal empilhado

# %% [markdown]
# ## 2.2 Histograms

# %%
df4 = pd.DataFrame({
    'a': np.random.randn(1000) + 1,
    'b': np.random.randn(1000),
    'c': np.random.randn(1000) - 1},
    columns=['a', 'b', 'c']
)

# %%
plt.figure();
df4.plot.hist(alpha=0.5)

# %%
plt.figure();
df4.plot.hist(stacked=True, bins=20) # empilhando os dados

# %%
plt.figure();
df4['a'].plot.hist(orientation='horizontal', cumulative=True)

# %%
plt.figure();

df['A'].diff().hist()

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.226476 -0.572371 -1.081703 -0.209298
# 2000-01-02  1.441315  0.028906 -1.203312 -0.620461
# 2000-01-03  1.824430  0.945587  0.419847  0.686270
# 2000-01-04  3.585721  2.467225  1.588002  0.736447
# 2000-01-05  1.956039  1.123336  2.620502  0.182234

# %%
plt.figure();
df.diff().hist(color='k', alpha=0.5, bins=50) # verificando a diferença dos valores das colunas
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002054F813AC8>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002054F893E80>]], dtype=object)

# %%
data = pd.Series(np.random.randn(1000))

# %%
data.head()
# Out:
# 0   -0.058222
# 1   -0.770050
# 2   -1.164162
# 3    0.453957
# 4    0.005565
# dtype: float64

# %%
data.hist(by=np.random.randint(0, 4, 1000), figsize=(6, 4))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002054F353400>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002054F9FF9E8>]], dtype=object)

# %% [markdown]
# ## 2.3 Box Plots

# %%
df = pd.DataFrame(np.random.rand(10,5), columns=['A', 'B', 'C', 'D', 'E'])
df
# Out:
#           A         B         C         D         E
# 0  0.545612  0.245091  0.728785  0.792153  0.438352
# 1  0.798428  0.981047  0.739552  0.494427  0.398746
# 2  0.080795  0.735283  0.246088  0.563198  0.910256
# 3  0.226609  0.266345  0.645196  0.598281  0.586151
# 4  0.800586  0.530130  0.601995  0.179295  0.781489
# 5  0.283108  0.021717  0.348229  0.755271  0.083237
# 6  0.320386  0.556466  0.165019  0.642850  0.696890
# 7  0.568628  0.749181  0.507733  0.377960  0.199569
# 8  0.555700  0.568745  0.505826  0.582902  0.656377
# 9  0.920296  0.938161  0.280975  0.193539  0.688248

# %%
df.plot.box()

# %%
color = dict(boxes='DarkGreen', whiskers='DarkOrange', medians='DarkBlue', caps='Gray')
color
# Out:
# {'boxes': 'DarkGreen',
#  'whiskers': 'DarkOrange',
#  'medians': 'DarkBlue',
#  'caps': 'Gray'}

# %%
df.plot.box(color=color, sym='r+')

# %%
df.plot.box(vert=False, positions=[1, 4, 5, 6, 8])

# %%
df = pd.DataFrame(np.random.rand(10, 5))

# %%
plt.figure();
bp = df.boxplot()

# %%
df = pd.DataFrame(np.random.rand(10, 2), columns=['Col1', 'Col2'])

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df
# Out:
#        Col1      Col2  X
# 0  0.067315  0.508719  A
# 1  0.661273  0.002202  A
# 2  0.426684  0.074307  A
# 3  0.892444  0.956658  A
# 4  0.545402  0.524948  A
# 5  0.495601  0.557658  B
# 6  0.180239  0.745778  B
# 7  0.458629  0.427950  B
# 8  0.788678  0.648536  B
# 9  0.466178  0.814716  B

# %%
df.boxplot()

# %%
plt.figure();
bp = df.boxplot(by='X')

# %%
df = pd.DataFrame(np.random.rand(10, 3), columns=['Col1', 'Col2', 'Col3'])

# %%
df['X'] = pd.Series(['A', 'A', 'A', 'A', 'A', 'B', 'B', 'B', 'B', 'B'])

# %%
df['Y'] = pd.Series(['A', 'B', 'A', 'B', 'A', 'B', 'A', 'B', 'A', 'B'])

# %%
df
# Out:
#        Col1      Col2      Col3  X  Y
# 0  0.724606  0.483921  0.536990  A  A
# 1  0.852249  0.403857  0.890324  A  B
# 2  0.680436  0.010449  0.406902  A  A
# 3  0.851910  0.981526  0.015604  A  B
# 4  0.676449  0.835164  0.508879  A  A
# 5  0.993251  0.192469  0.788696  B  B
# 6  0.147889  0.829132  0.013443  B  A
# 7  0.976455  0.729952  0.938375  B  B
# 8  0.719475  0.006095  0.487482  B  A
# 9  0.074899  0.889740  0.648175  B  B

# %%
plt.figure();

# %%
bp = df.boxplot()

# %%
bp = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])

# %%
bp = df.boxplot(column=['Col1', 'Col2'], by=['X', 'Y'])

# %%
np.random.seed(1234)

# %%
df_box = pd.DataFrame(np.random.randn(50,2))

# %%
df_box['g'] = np.random.choice(['A', 'B'], size=50)

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  0.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696 -2.242685  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646 -0.655969  B
# 11  0.193421  0.553439  B
# 12  1.318152 -0.469305  B
# 13  0.675554 -1.817027  B
# 14 -0.183109  1.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  1.045938  B
# 17  0.863717 -0.122092  B
# 18  0.124713 -0.322795  B
# 19  0.841675  2.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142 -2.074978  B
# 22  0.247792 -0.897157  B
# 23 -0.136795  0.018289  B
# 24  0.755414  0.215269  B
# 25  0.841009 -1.445810  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242 -0.144620  B
# 28  0.354020 -0.035513  B
# 29  0.565738  1.545659  A
# 30 -0.974236 -0.070345  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# ...

# %%
df_box.loc[df_box['g'] == 'B', 1] += 3

# %%
df_box
# Out:
#            0         1  g
# 0   0.471435 -1.190976  A
# 1   1.432707 -0.312652  A
# 2  -0.720589  3.887163  B
# 3   0.859588 -0.636524  A
# 4   0.015696  0.757315  B
# 5   1.150036  0.991946  A
# 6   0.953324 -2.021255  A
# 7  -0.334077  0.002118  A
# 8   0.405453  0.289092  A
# 9   1.321158 -1.546906  A
# 10 -0.202646  2.344031  B
# 11  0.193421  3.553439  B
# 12  1.318152  2.530695  B
# 13  0.675554  1.182973  B
# 14 -0.183109  4.058969  B
# 15 -0.397840  0.337438  A
# 16  1.047579  4.045938  B
# 17  0.863717  2.877908  B
# 18  0.124713  2.677205  B
# 19  0.841675  5.390961  B
# 20  0.076200 -0.566446  A
# 21  0.036142  0.925022  B
# 22  0.247792  2.102843  B
# 23 -0.136795  3.018289  B
# 24  0.755414  3.215269  B
# 25  0.841009  1.554190  B
# 26 -1.401973 -0.100918  A
# 27 -0.548242  2.855380  B
# 28  0.354020  2.964487  B
# 29  0.565738  1.545659  A
# 30 -0.974236  2.929655  B
# 31  0.307969 -0.208499  A
# 32  1.033801 -2.400454  A
# 33  2.030604 -1.142631  A
# ...

# %%
dp = df_box.boxplot(by='g')

# %%
dp = df_box.groupby('g').boxplot()

# %% [markdown]
# ## 2.4 Area Plot

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.area()

# %%
df.plot.area(stacked=False)

# %% [markdown]
# ## 2.5 Scatter Plot

# %%
# %matplotlib inline

# %%
df = pd.DataFrame(np.random.rand(50,4), columns=['a', 'b', 'c', 'd'])

# %%
df.plot.scatter(x='a', y='b')

# %%
ax = df.plot.scatter(x='a', y='b', color='DarkBlue', label='Group 1')

# %%
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2')

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.figure();
df.plot.scatter(x='c', y='d', color='DarkGreen', label='Group 2', ax=ax);

# %%
plt.show()

# %%
df.plot.scatter(x='a', y='b', c='c', s=50);

# %%
df.plot.scatter(x='a', y='b', s=df['c']*200);

# %% [markdown]
# ## 2.6 Hexagonal Bin Plot

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] + np.arange(1000)

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])

# %%
df['b'] = df['b'] = df['b'] + np.arange(1000)

# %%
df['z'] = np.random.uniform(0, 3, 1000)

# %%
df.plot.hexbin(x='a', y='b', C='z', reduce_C_function=np.max, gridsize=25)

# %% [markdown]
# ## 2.7 Pie plot

# %%
series = pd.Series(3 * np.random.rand(4), index=['a',' b', 'c', 'd'], name='series')

# %%
series.plot.pie(figsize=(6, 6))

# %%
df = pd.DataFrame(3 * np.random.rand(4, 2), index=['a', 'b', 'c', 'd'], columns=['x', 'y'])

# %%
df
# Out:
#           x         y
# a  1.723781  1.034762
# b  0.228865  2.799262
# c  0.217145  2.294694
# d  2.883440  2.384940

# %%
df.plot.pie(subplots = True, figsize=(8, 4))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000205517C1438>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x00000205517DF9B0>], dtype=object)

# %%
series.plot.pie(labels=['AA', 'BB', 'CC', 'DD'], colors=['r', 'g', 'b', 'c'],
               autopct='%.2f', fontsize=20, figsize=(6,6))

# %%
series = pd.Series([0.1] * 4, index=['a', 'b', 'c', 'd'], name='series2')

# %%
series.plot.pie(figsize=(6,6))

# %% [markdown]
# # 3 Plotting Tools

# %% [markdown]
# ## 3.1 Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix

# %%
df = pd.DataFrame(np.random.randn(1000, 4), columns=['a', 'b', 'c', 'd'])

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.737131  0.051757 -1.120734  1.788603
# 1 -0.801182  1.031012 -0.054130  1.015754
# 2  1.448304  0.306453 -1.357104 -1.684708
# 3 -0.602216 -1.263121  0.430573  0.088253
# 4 -0.667779  0.909468  0.025300 -1.251889

# %%
scatter_matrix(df, alpha=0.2, figsize=(6,6), diagonal='kde')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000205518D5C88>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000020551B67F98>]], dtype=object)

# %% [markdown]
# ## 3.2 Density Plot

# %%
ser = pd.Series(np.random.randn(1000))

# %%
ser.plot.kde()

# %% [markdown]
# ## 3.3 Andrews Curves

# %% [raw]
# Gera um grafico com formato de Séries de Fourier

# %%
from pandas.plotting import andrews_curves

# %%
data = pd.read_csv('../data/pydata/iris.data')

# %%
data
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# 7            5.0         3.4          1.5         0.2     Iris-setosa
# 8            4.4         2.9          1.4         0.2     Iris-setosa
# 9            4.9         3.1          1.5         0.1     Iris-setosa
# 10           5.4         3.7          1.5         0.2     Iris-setosa
# 11           4.8         3.4          1.6         0.2     Iris-setosa
# ...

# %%
plt.figure()

# %%
andrews_curves(data, 'Name')

# %% [markdown]
# ## 3.4 Parallel Coodinates

# %%
from pandas.plotting import parallel_coordinates

# %%
data = pd.read_csv('../data/pydata/iris.data')

# %%
plt.figure()

# %%
parallel_coordinates(data, 'Name')

# %% [markdown]
# ## 3.5 Lag Plot

# %%
from pandas.plotting import lag_plot

# %%
plt.figure()

# %%
data = pd.Series(0.1 * np.random.rand(1000) + 0.9 * np.sin(np.linspace(-99 * np.pi, 99 * np.pi, num=1000)))

# %%
data
# Out:
# 0      0.056058
# 1     -0.473362
# 2     -0.846289
# 3     -0.794663
# 4     -0.453265
# 5      0.061843
# 6      0.535722
# 7      0.937650
# 8      0.961160
# 9      0.582479
# 10     0.100968
# 11    -0.428661
# 12    -0.791598
# 13    -0.835729
# 14    -0.537417
# 15    -0.066967
# 16     0.463025
# 17     0.831533
# 18     0.979699
# 19     0.661387
# 20     0.187799
# 21    -0.422511
# 22    -0.748438
# 23    -0.821028
# 24    -0.576376
# 25    -0.100711
# 26     0.444563
# 27     0.901666
# 28     0.958397
# 29     0.642366
#          ...
# 970   -0.545001
# 971   -0.871915
# 972   -0.796193
# 973   -0.379916
# 974    0.157146
# 975    0.662309
# 976    0.969445
# 977    0.913423
# 978    0.464404
# 979   -0.003704
# 980   -0.597652
# 981   -0.870307
# 982   -0.789880
# 983   -0.371247
# 984    0.116978
# 985    0.630748
# 986    0.936698
# 987    0.852263
# 988    0.540898
# 989   -0.036811
# 990   -0.505559
# 991   -0.855895
# 992   -0.756274
# 993   -0.437694
# ...

# %%
lag_plot(data)

# %% [markdown]
# ## 3.6 Autocorrelation Plot

# %%
from pandas.plotting import autocorrelation_plot

# %%
plt.figure()

# %%
data = pd.Series(0.7 * np.random.rand(1000) + 0.3 * np.sin(np.linspace(-9 * np.pi, 9 * np.pi, num=1000)))

# %%
autocorrelation_plot(data)

# %% [markdown]
# ## 3.7 Bootstrap Plot

# %%
from pandas.plotting import bootstrap_plot

# %%
data = pd.Series(np.random.rand(1000))

# %%
bootstrap_plot(data, size=50, color='grey')

# %% [markdown]
# ## 3.8 RadViz

# %%
from pandas.plotting import radviz

# %%
data = pd.read_csv('../data/pydata/iris.data')

# %%
plt.figure()

# %%
radviz(data, 'Name')

# %% [markdown]
# # 4 Plot Formating

# %% [markdown]
# ## 4.1 General plot style arguments

# %%
ts
# Out:
# 2000-01-01    2.956089
# 2000-01-02    3.321549
# 2000-01-03    2.249573
# 2000-01-04    0.508242
# 2000-01-05    0.640433
# 2000-01-06   -1.527203
# 2000-01-07   -1.361034
# 2000-01-08   -1.743628
# 2000-01-09   -0.072564
# 2000-01-10    0.811639
# 2000-01-11    0.107190
# 2000-01-12   -0.002046
# 2000-01-13    0.180911
# 2000-01-14   -0.257657
# 2000-01-15   -0.183398
# 2000-01-16   -0.923558
# 2000-01-17   -1.089384
# 2000-01-18   -0.935309
# 2000-01-19   -1.383857
# 2000-01-20   -1.988433
# 2000-01-21   -1.969959
# 2000-01-22   -2.176559
# 2000-01-23   -3.257110
# 2000-01-24   -2.789094
# 2000-01-25   -3.203841
# 2000-01-26   -4.153194
# 2000-01-27   -3.811322
# 2000-01-28   -3.963543
# 2000-01-29   -5.645058
# 2000-01-30   -6.693892
#                 ...
# 2002-08-28    8.078111
# 2002-08-29    8.331385
# 2002-08-30    6.998945
# 2002-08-31    8.070752
# 2002-09-01    7.368892
# 2002-09-02    8.152214
# 2002-09-03    5.963396
# 2002-09-04    4.715146
# 2002-09-05    3.884890
# ...

# %%
plt.figure(); ts.plot(style='k--', label='Series')

# %% [markdown]
# ## 4.2 Controlling the legend

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=list('ABCD'))

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.033702  1.168043 -2.206660 -1.131964
# 2000-01-02 -0.273702 -2.714794  0.636696 -1.265272
# 2000-01-03  0.115135 -0.181975 -0.707999  0.276663
# 2000-01-04 -0.364119 -0.576744  0.783282  0.804460
# 2000-01-05 -1.082217 -0.995701 -0.389578 -0.198801

# %%
df = df.cumsum()

# %%
df.plot(legend=False)

# %%
df.plot(legend=True)

# %% [markdown]
# ## 4.3 Scales

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))

# %%
ts = np.exp(ts.cumsum())

# %%
ts.head(10)
# Out:
# 2000-01-01     2.198654
# 2000-01-02     5.246466
# 2000-01-03     2.375968
# 2000-01-04     0.751994
# 2000-01-05     7.029228
# 2000-01-06    17.338914
# 2000-01-07    14.922062
# 2000-01-08     4.270702
# 2000-01-09    16.668340
# 2000-01-10    14.357042
# Freq: D, dtype: float64

# %%
ts.plot(logy=True)

# %%
ts.plot(logy=False)

# %% [markdown]
# ## 4.4 Plotting on a Secondary Y-axis

# %%
df.A.head(10)
# Out:
# 2000-01-01    0.033702
# 2000-01-02   -0.239999
# 2000-01-03   -0.124864
# 2000-01-04   -0.488983
# 2000-01-05   -1.571200
# 2000-01-06   -0.785460
# 2000-01-07   -1.076738
# 2000-01-08   -2.000423
# 2000-01-09   -1.370719
# 2000-01-10    0.407407
# Freq: D, Name: A, dtype: float64

# %%
df.A.plot();

# %%
df.B.plot(secondary_y=True, style='g')

# %%
plt.figure()

# %%
ax.set_ylabel('CD scale')
# Out:
# Text(17.2,0.5,'CD scale')

# %%
ax = df.plot(secondary_y=['A', 'B'])

# %%
plt.figure()

# %%
df.plot(secondary_y=['A', 'B'], mark_right = False)

# %% [markdown]
# ## 4.5 Suppressing Tick Resolution Adjustment

# %%
plt.figure()

# %%
df.A.plot()

# %%
plt.figure()

# %%
df.A.plot(x_compat=True)

# %%
plt.figure()

# %%
with pd.plotting.plot_params.use('x_compat', True):
    df.A.plot(color='r')
    df.B.plot(color='g')
    df.C.plot(color='b')

# %%
with pd.plotting.plot_params.use('x_compat', False):
    df.A.plot(color='r')
    df.B.plot(color='g')
    df.C.plot(color='b')

# %% [markdown]
# # 5 Automatic Date Tick Adjustment

# %% [markdown]
# ## 5.1 Subplots

# %%
df.head()
# Out:
#                    A         B         C         D
# 2000-01-01  0.033702  1.168043 -2.206660 -1.131964
# 2000-01-02 -0.239999 -1.546751 -1.569964 -2.397236
# 2000-01-03 -0.124864 -1.728725 -2.277963 -2.120573
# 2000-01-04 -0.488983 -2.305469 -1.494681 -1.316113
# 2000-01-05 -1.571200 -3.301171 -1.884260 -1.514914

# %%
df.plot(subplots=True, figsize=(15,6))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002055671E940>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002055679D6D8>], dtype=object)

# %% [markdown]
# ## 5.2 Using Layout and Targeting Multiple Axes

# %%
df.plot(subplots=True, layout=(2,3), figsize=(10,6), sharex=False);

# %%
df.plot(subplots=True, layout=(2, -1), figsize=(6, 6), sharex=False);
fig, axes = plt.subplots(4, 4, figsize=(6, 6));
plt.subplots_adjust(wspace=0.5, hspace=0.5);

target1 = [axes[0][0], axes[1][1], axes[2][2], axes[3][3]]

target2 = [axes[3][0], axes[2][1], axes[1][2], axes[0][3]]

df.plot(subplots=True, ax=target1, legend=False, sharex=False, sharey=False);
(-df).plot(subplots=True, ax=target2, legend=False, sharex=False, sharey=False);

# %% [markdown]
# ## 5.3  Plotting With Error Bars

# %%
ix3 = pd.MultiIndex.from_arrays([
    ['a', 'a', 'a', 'a', 'b', 'b', 'b', 'b'],
    ['foo', 'foo', 'bar', 'bar', 'foo', 'foo', 'bar', 'bar']
], names=['letter', 'word'])

# %%
df3 = pd.DataFrame({
    'data1': [3, 2, 4, 3, 2, 4, 3, 2],
    'data2': [6, 5, 7, 5, 4, 5, 6, 5]
}, index=ix3)

# %%
df3
# Out:
#              data1  data2
# letter word
# a      foo       3      6
#        foo       2      5
#        bar       4      7
#        bar       3      5
# b      foo       2      4
#        foo       4      5
#        bar       3      6
#        bar       2      5

# %%
gp3 = df3.groupby(level=('letter', 'word'))

# %%
gp3

# %%
means = gp3.mean(); means
# Out:
#              data1  data2
# letter word
# a      bar     3.5    6.0
#        foo     2.5    5.5
# b      bar     2.5    5.5
#        foo     3.0    4.5

# %%
errors = gp3.std(); errors
# Out:
#                 data1     data2
# letter word
# a      bar   0.707107  1.414214
#        foo   0.707107  0.707107
# b      bar   0.707107  0.707107
#        foo   1.414214  0.707107

# %%
fig, axes = plt.subplots()
means.plot.bar(yerr=errors, ax=axes)

# %% [markdown]
# ## 5.4 Plotting Tables

# %%
fig, ax = plt.subplots(1,1)

df = pd.DataFrame(np.random.rand(5, 3), columns=['a', 'b', 'c'])

ax.get_xaxis().set_visible(False) 

df.plot(table=True, ax=ax)

# %%
fig, ax = plt.subplots(1, 1)
ax.get_xaxis().set_visible(False)
df.plot(table=np.round(df.T, 2), ax=ax)

# %%
from pandas.plotting import table

# %%
df.describe()
# Out:
#               a         b         c
# count  5.000000  5.000000  5.000000
# mean   0.459810  0.630349  0.560088
# std    0.178188  0.309652  0.219686
# min    0.175311  0.294178  0.308357
# 25%    0.418468  0.366459  0.384738
# 50%    0.519382  0.603909  0.549001
# 75%    0.541194  0.899217  0.741666
# max    0.644695  0.987982  0.816679

# %%
np.round(df.describe(), 2) # arredondar
# Out:
#           a     b     c
# count  5.00  5.00  5.00
# mean   0.46  0.63  0.56
# std    0.18  0.31  0.22
# min    0.18  0.29  0.31
# 25%    0.42  0.37  0.38
# 50%    0.52  0.60  0.55
# 75%    0.54  0.90  0.74
# max    0.64  0.99  0.82

# %%
fig, ax = plt.subplots(1, 1);

table(ax, np.round(df.describe(), 2), loc='upper right', colWidths=[0.2, 0.2, 0.2]) # muito útil!

df.plot(ax=ax, ylim=(0, 2), legend=None)

# %% [markdown]
# ## 5.5 Colormaps

# %%
df = pd.DataFrame(np.random.randn(1000, 10), index=ts.index)

# %%
df = df.cumsum()

# %%
df.head()
# Out:
#                    0         1         2         3         4         5  \
# 2000-01-01  0.468382 -0.335218 -0.615620  1.412405  2.322690  0.135825
# 2000-01-02  1.937068  0.854984 -2.241840  0.699490  3.764858 -0.443418
# 2000-01-03  2.203507 -0.257087 -1.505331 -0.523067  3.680301 -0.395167
# 2000-01-04  4.123437 -1.369727 -0.671687  0.167453  3.369606 -1.045493
# 2000-01-05  3.254002 -0.857922 -0.387478  1.047284  3.425038 -1.983093
#
#                    6         7         8         9
# 2000-01-01  0.944482 -0.174968  1.113256 -1.338833
# 2000-01-02  0.442355 -0.313239  0.595397 -1.945306
# 2000-01-03  0.226439 -0.251942  1.007500 -3.209293
# 2000-01-04 -1.552065  0.272029  1.211241 -2.683229
# 2000-01-05 -2.467776  0.149774  0.553591 -2.515301

# %%
plt.figure()

# %%
df.plot(colormap='cubehelix', figsize=(10,10))

# %%
from matplotlib import cm

# %%
plt.figure()

# %%
df.plot(colormap=cm.cubehelix, figsize=(10,10)) # outra forma de obter o mesmo resultado

# %%
dd = pd.DataFrame(np.random.randn(10, 10)).applymap(abs)

# %%
dd = dd.cumsum()

# %%
dd.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0  0.727055  0.585745  0.710020  0.467665  0.459505  1.047028  0.356822
# 1  1.495861  1.626524  1.471293  1.531270  1.026915  2.232123  0.535553
# 2  1.629983  2.055532  2.247272  3.008227  2.111428  2.383289  0.820408
# 3  2.021730  3.431067  2.755415  3.196761  3.025535  3.226401  1.786173
# 4  2.499172  4.770941  3.834966  5.271819  4.797652  3.854796  2.400940
#
#           7         8         9
# 0  0.708877  0.867666  0.360556
# 1  0.709241  2.841798  1.654579
# 2  2.855070  4.675392  1.980634
# 3  4.005624  5.871063  2.072313
# 4  4.325659  6.366836  2.788940

# %%
plt.figure()

# %%
dd.plot.bar(colormap='Greens', figsize=(10, 6))

# %%
plt.figure()

# %%
parallel_coordinates(data, 'Name', colormap='gist_rainbow')

# %%
plt.figure()

# %%
andrews_curves(data, 'Name', colormap='winter')

# %% [markdown]
# # 6 Plotting directly with matplotlib

# %%
price = pd.Series(np.random.randn(150).cumsum(),
                 index=pd.date_range('2000-1-1', periods=150, freq='B'))

# %%
price.head()
# Out:
# 2000-01-03    0.815461
# 2000-01-04    2.969290
# 2000-01-05    2.128816
# 2000-01-06    1.125159
# 2000-01-07    0.727628
# Freq: B, dtype: float64

# %%
ma = price.rolling(20).mean()

# %%
mstd = price.rolling(20).std()

# %%
plt.figure()

# %%
plt.plot(price.index, price, 'k')

plt.plot(ma.index, ma, 'b')

plt.fill_between(mstd.index, ma-2*mstd, ma+2*mstd, color='b', alpha=0.2)
